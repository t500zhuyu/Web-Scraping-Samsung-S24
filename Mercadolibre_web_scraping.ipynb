# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# get the url from the mercado libre website, searching for samsung s24 general listing with all the products available
url = "https://listado.mercadolibre.com.mx/samsung-s24#D[A:samsung%20s24]"

# %%
# headers for request
# to know browser : https://www.whatismybrowser.com/detect/what-is-my-user-agent/
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

# %%
# http request
webpage = requests.get(url, headers=HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
# Soup object containiang all data in html format
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es-MX">
# ...

# %%
# Fetch links as list of tag objects, html with the link
links = soup.find_all("a", attrs={'class': 'ui-search-item__group__element ui-search-link__title-card ui-search-link'})

# %%
links
# Out:
# [<a class="ui-search-item__group__element ui-search-link__title-card ui-search-link" href="https://www.mercadolibre.com.mx/samsung-galaxy-s24-ultra-5g-dual-sim-512-gb-violeta-titanio-12-gb-ram/p/MLM29893911#searchVariation=MLM29893911&amp;position=9&amp;search_layout=stack&amp;type=product&amp;tracking_id=0601a430-171f-43b3-ab69-50a91031988f" title="Samsung Galaxy S24 Ultra 5G Dual SIM 512 GB violeta titanio 12 GB RAM"><h2 aria-level="3" class="ui-search-item__title">Samsung Galaxy S24 Ultra 5G Dual SIM 512 GB violeta titanio 12 GB RAM</h2></a>,
# ...

# %%
# Extract the actual link
# links[0]

# getting the link format
# links[0].get('href')

# getting the link variable
link = links[0].get('href')

# %%
# to work the link I had to add the .mx because I'm using amazon.com.mx website, it changes
# according with the nation amazon site
product_list = link
product_list
# Out:
# 'https://www.mercadolibre.com.mx/samsung-galaxy-s24-ultra-5g-dual-sim-512-gb-violeta-titanio-12-gb-ram/p/MLM29893911#searchVariation=MLM29893911&position=9&search_layout=stack&type=product&tracking_id=0601a430-171f-43b3-ab69-50a91031988f'

# %%
new_webpage = requests.get(product_list, headers=HEADERS)
new_webpage
# Out:
# <Response [200]>

# %%
# NEW SOUP 
new_soup = BeautifulSoup(new_webpage.content, "html.parser")
new_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es-MX">
# ...

# %%
# Title of the product
# new_soup.find("span", attrs={"id":"productTitle"})
# new_soup.find("span", attrs={"id":"productTitle"}).text
new_soup.find("h1", attrs={"class":"ui-pdp-title"}).text
# Out:
# 'Samsung Galaxy S24 Ultra 5G Dual SIM 512 GB violeta titanio 12 GB RAM'

# %%
# getting the price
new_soup.find("span", attrs={"class":"andes-money-amount__fraction"}).text.strip()
# Out:
# '20,223'

# %%
# getting the reviews
new_soup.find("span", attrs={"class":"ui-pdp-review__rating"}).text.strip()
# Out:
# '4.7'

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("h1", attrs={"class":'ui-pdp-title'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':'andes-money-amount__fraction'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'class':'andes-money-amount__fraction'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("span", attrs={'class':'ui-pdp-review__rating'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'ui-pdp-review__rating'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'class':'ui-pdp-review__amount'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
#def get_availability(soup):
 #   try:
   #     available = soup.find("div", attrs={'id':'availability'})
    #    available = available.find("span").string.strip()

   # except AttributeError:
    #    available = "Not Available"	

   # return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    url = "https://listado.mercadolibre.com.mx/samsung-s24#D[A:samsung%20s24]"

    # HTTP Request
    webpage = requests.get(url, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class': 'ui-search-item__group__element ui-search-link__title-card ui-search-link'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get(link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        #d['availability'].append(get_availability(new_soup))

    
    mercadolibre_df = pd.DataFrame.from_dict(d)
    mercadolibre_df['title'].replace('', np.nan, inplace=True)
    mercadolibre_df = amazon_df.dropna(subset=['title'])
    mercadolibre_df.to_csv("mercadolibresams24_data.csv", header=True, index=False)

# %%
mercadolibre_df
# Out:
#                                                 title   price rating reviews
# 0   Samsung Galaxy S24 Ultra 5G Dual SIM 512 GB vi...  20,247
# 1   Samsung Galaxy A05s Dual SIM 128 GB negro 4 GB...   2,185
# 2   Samsung Galaxy S24 Ultra 5G Dual SIM 256 GB ne...  20,195
# 3   Samsung Galaxy S24 Plus (Exynos) 5G Dual SIM 2...  16,795
# 4   Samsung Galaxy S23 Dual SIM 128 GB lavander 8 ...  11,799
# 5   Samsung Galaxy S24 5G Dual SIM 256 GB cobalt v...  13,995
# 6   Samsung Galaxy S24 Plus 5G Dual SIM 256 GB gri...  33,980
# 7   Samsung Galaxy S24 Ultra, Galaxy Ai, Gris Marm...  29,799    4.7    (30)
# 8   Samsung Galaxy S24 Plus 5G Dual SIM 512 GB neg...  26,518
# 9   Samsung Galaxy S24 Ultra (Dual eSIM) 5G 256 GB...  29,999
# 10  Samsung Galaxy S24 Ultra (Dual eSIM) 5G Galaxy...  29,999
# 11  Samsung Galaxy S24 5G Dual SIM 256 GB amarillo...  15,512    4.9    (96)
# 12  Samsung Galaxy S24 Ultra 5G Dual SIM 512 GB gr...  21,978
# ...
